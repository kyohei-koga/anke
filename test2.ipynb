# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
columns = pd.read_excel('/home/kyohei/NEDO_anke_data/NEDO_H24.xlsx').columns
data = pd.read_excel('/home/kyohei/NEDO_anke_data/NEDO_H24.xlsx',skiprows=6,skip_footer=12)
data.columns = columns

# %%
data.head()
# Out:
#   担当部課名 プロジェクト番号                                            プロジェクト名  \
# 0   環境部   P09010  グリーン・サステナブルケミカルプロセス基盤技術開発／①有害な化学物質を削減できる、又は使わな...
# 1   環境部   P09010  グリーン・サステナブルケミカルプロセス基盤技術開発／①有害な化学物質を削減できる、又は使わな...
# 2   環境部   P09010  グリーン・サステナブルケミカルプロセス基盤技術開発／①有害な化学物質を削減できる、又は使わな...
# 3   環境部   P09010  グリーン・サステナブルケミカルプロセス基盤技術開発／①有害な化学物質を削減できる、又は使わな...
# 4   環境部   P09010  グリーン・サステナブルケミカルプロセス基盤技術開発／①有害な化学物質を削減できる、又は使わな...
#
#           機関名    相手方コード     シートNo  大分野  委託区分（委託、再委託等）  \
# 0     ＪＮＣ株式会社  828787.0  11060388    1              1
# 1  荒川化学工業株式会社  800983.0  11060387    1              1
# 2    昭和電工株式会社  804100.0  11060381    1              1
# 3    昭和電工株式会社  804100.0  11060385    1              1
# 4  電気化学工業株式会社  700492.0  11060386    1              1
#
#             テーマ名（委託先、再委託先等のプロジェクト期間中）        所属機関名 ...  Q52_error  Q52_予算削減  \
# 0                       難酸化性基質の酸化技術開発  JNC石油化学株式会社 ...        NaN       1.0
# 1                     易加水分解性基質の酸化技術開発   荒川化学工業株式会社 ...        NaN       NaN
# 2  アクア触媒によるアセトアルデヒド製造プラント排水中の希薄酢酸回収技術     昭和電工株式会社 ...        NaN       NaN
# 3                       多官能性基質の酸化技術開発     昭和電工株式会社 ...        NaN       NaN
# 4                       高分子量基質の酸化技術開発   電気化学工業株式会社 ...        NaN       NaN
#
#    Q52_柔軟な計画変更  Q52_中止のタイミング  Q52_評価のタイミング  Q52_事務手続きの改善 Q52_その他  Q52_記述欄  \
# 0          NaN           NaN           NaN           NaN     NaN      NaN
# 1          1.0           NaN           NaN           1.0     NaN      NaN
# 2          1.0           1.0           NaN           1.0     NaN      NaN
# 3          NaN           NaN           NaN           NaN     NaN      NaN
# 4          NaN           NaN           NaN           1.0     NaN      NaN
#
#                                      Q52_具体的  Q53
# 0  加速資金の利用でPJで重要な要素技術の開発が早期に目処がたち良かったと考えている。  1.0
# 1                                        NaN  1.0
# 2                                        NaN  1.0
# 3                           より柔軟な予算運営を希望します。  2.0
# 4                    事務手続の簡略化（代表社印の必要性の検討等）。  1.0
#
# [5 rows x 515 columns]
